# %%
import pandas as pd
import numpy as np

# %%
patients=pd.read_csv('IndividualDetails.csv')

# %%
patients.head()
# Out:
#    id government_id diagnosed_date  age gender             detected_city  \
# 0   0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1   1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2   2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3   3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4   4         TS-P1     02/03/2020   24      M                 Hyderabad
#
#   detected_district detected_state nationality current_status  \
# 0          Thrissur         Kerala       India      Recovered
# 1         Alappuzha         Kerala       India      Recovered
# 2         Kasaragod         Kerala       India      Recovered
# 3        East Delhi          Delhi       India      Recovered
# 4         Hyderabad      Telangana       India      Recovered
#
#   status_change_date                                              notes
# 0         14/02/2020                               Travelled from Wuhan
# ...

# %%
patients['current_status'].value_counts()
# Out:
# current_status
# Hospitalized    8301
# Recovered        139
# Deceased          30
# Migrated           1
# Name: count, dtype: int64

# %%
total=patients.shape[0]
active=patients[patients['current_status']=='Hospitalized']
recovered=patients[patients['current_status']=='Recovered']
death=patients[patients['current_status']=='Deceased']

# %%
total
# Out:
# 8472

# %%
active
# Out:
#         id government_id diagnosed_date  age gender detected_city  \
# 18      18           NaN     04/03/2020   55    NaN      Gurugram
# 19      19           NaN     04/03/2020   55    NaN      Gurugram
# 21      21           NaN     04/03/2020  NaN      M          Agra
# 26      26           NaN     04/03/2020  NaN    NaN          Agra
# 27      27           NaN     04/03/2020  NaN    NaN           NaN
# ...    ...           ...            ...  ...    ...           ...
# 8467  8468           NaN     12/04/2020  NaN    NaN           NaN
# 8468  8469           NaN     12/04/2020  NaN    NaN           NaN
# 8469  8470           NaN     12/04/2020  NaN    NaN           NaN
# 8470  8471           NaN     12/04/2020  NaN    NaN           NaN
# 8471  8472           NaN     12/04/2020  NaN    NaN           NaN
#
#      detected_district detected_state nationality current_status  \
# 18           Italians*        Haryana       Italy   Hospitalized
# ...

# %%
recovered
# Out:
#         id government_id diagnosed_date  age gender             detected_city  \
# 0        0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1        1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2        2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3        3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4        4         TS-P1     02/03/2020   24      M                 Hyderabad
# ...    ...           ...            ...  ...    ...                       ...
# 1078  1078        TN-P46     29/03/2020   51      F                       NaN
# 1248  1248           NaN     30/03/2020  NaN    NaN                       NaN
# 1249  1249           NaN     30/03/2020  NaN    NaN                       NaN
# 1250  1250           NaN     30/03/2020  NaN    NaN                       NaN
# 1260  1260           NaN     30/03/2020  NaN    NaN                       NaN
#
# ...

# %%
death
# Out:
#         id government_id diagnosed_date  age gender detected_city  \
# 71      71         DL-P6     12/03/2020   69      F     Janakpuri
# 73      73         KA-P6     13/03/2020   76      M    Kalaburagi
# 76      76           NaN     12/03/2020   65      M        Mumbai
# 181    181         PJ-P2     19/03/2020   70      M         Banga
# 269    269           NaN     21/03/2020   63      M        Mumbai
# 293    293           NaN     21/03/2020   67      M         Surat
# 326    326         WB-P4     21/03/2020   57      M       Dum Dum
# 347    347           NaN     22/03/2020   38      M        Munger
# 379    379           NaN     22/03/2020   69      M
# 429    429           NaN     23/03/2020   85      F     Ahmedabad
# 486    486           NaN     23/03/2020   69      M        Kangra
# 501    501        TN-P12     23/03/2020   54      M       Madurai
# 530    530           NaN     24/03/2020   65      M           NaN
# ...

# %%
patients['detected_district'].value_counts().reset_index().reset_index()
# Out:
#      index  detected_district  count
# 0        0             Mumbai   1146
# 1        1             Jaipur    301
# 2        2             Indore    281
# 3        3               Pune    257
# 4        4          Ahmadabad    243
# ..     ...                ...    ...
# 348    348              Dahod      1
# 349    349          Dhenkanal      1
# 350    350            Tenkasi      1
# 351    351  Sri Muktsar Sahib      1
# 352    352         Vijayapura      1
#
# [353 rows x 3 columns]

# %%
options=[status for status in patients['current_status'].unique() if pd.notna(status)]
options
# Out:
# ['Recovered', 'Hospitalized', 'Deceased', 'Migrated']
